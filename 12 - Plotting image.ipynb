# %% [markdown]
# ![Alireza.png](attachment:Alireza.png)

# %% [markdown]
# ## 12 - Ploting the image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
image = cv2.imread("/Users/alireza/Coding/OpenCV_Learning/OpenCV_Learnings/Images/img.jpg",cv2.IMREAD_COLOR_RGB)
plt.imshow(image)

# %%
image = cv2.imread("/Users/alireza/Coding/OpenCV_Learning/OpenCV_Learnings/Images/img.jpg")
rgb_image = cv2.cvtColor(image,cv2.COLOR_RGB2GRAY) # converting color of image from BGR to RGB or Gray
plt.imshow(rgb_image , cmap="gray")

# %% [markdown]
# ### Source :
#
# https://www.geeksforgeeks.org/python/opencv-python-tutorial/
