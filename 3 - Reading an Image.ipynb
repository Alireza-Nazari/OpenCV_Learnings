# %% [markdown]
# ![alireza.png](attachment:alireza.png)

# %% [markdown]
# ## 3 - Reading an image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("/Users/alireza/Coding/OpenCV_Learning/OpenCV_Learnings/Images/img.jpg")
image # if we want to show the image we need to use imshow or matplotlib
plt.imshow(image)

# %% [markdown]
# images are in BGR in OpenCV in order to have the real image wee need to convert them into RGB form

# %%
image = cv2.imread("/Users/alireza/Coding/OpenCV_Learning/OpenCV_Learnings/Images/img.jpg")
real_image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(real_image)

# %% [markdown]
# ### Source :
#
# https://www.geeksforgeeks.org/python/opencv-python-tutorial/
