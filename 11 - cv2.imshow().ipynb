# %% [markdown]
# ## 1️⃣1️⃣ - cv2.imshow() method

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r'/Users/alireza/Coding/OpenCV_Learning/OpenCV_Learnings/Images/img.jpg'
image = cv2.imread(path, 0) # 0 means gray scale
plt.imshow(image)
cv2.waitKey(1000)
# Out:
# -1

# %% [markdown]
# ![image.png](attachment:image.png)
