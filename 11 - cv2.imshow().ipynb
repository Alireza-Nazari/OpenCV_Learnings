# %% [markdown]
# ![Alireza.png](attachment:Alireza.png)

# %% [markdown]
# ## 11 - Showing images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path = r'/Users/alireza/Coding/OpenCV_Learning/OpenCV_Learnings/Images/img.jpg'
image = cv2.imread(path, 0) # 0 means gray scale
plt.imshow(image) # instead of cv2.imshow("name" , file)
cv2.waitKey(1000)
# Out:
# -1

# %% [markdown]
# ### Source :
#
# https://www.geeksforgeeks.org/python/opencv-python-tutorial/
