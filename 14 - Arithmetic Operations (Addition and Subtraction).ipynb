# %% [markdown]
# ![Alireza.png](attachment:Alireza.png)

# %% [markdown]
# ## 14 - Arithmetic Operations (Addition and Subtraction)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image1 = cv2.imread("/Users/alireza/Coding/OpenCV_Learning/OpenCV_Learnings/Images/img.jpg",cv2.COLOR_BAYER_BG2GRAY)
image2 = cv2.imread("/Users/alireza/Coding/OpenCV_Learning/OpenCV_Learnings/Images/Stanford_University_Logo_full.png",cv2.COLOR_BAYER_BG2GRAY)
image2 = cv2.resize(image2, (image1.shape[1], image1.shape[0]))
#to have the in same size

#add_image = cv2.addWeighted(image1,0.2,image2,0.5,0.4)
weightedSum = cv2.addWeighted(image1, 0.5, image2, 0.4, 0)
plt.imshow(weightedSum)
# 🚨 image1 and image2 do not have the same size or number of channels, which is required for cv2.addWeighted().
# Out:
# -1

# %% [markdown]
# ## Subtract

# %%
image1 = cv2.imread("/Users/alireza/Coding/OpenCV_Learning/OpenCV_Learnings/Images/star-1-300x168.jpg")
plt.imshow(image1)

# %%
image2 = cv2.imread("/Users/alireza/Coding/OpenCV_Learning/OpenCV_Learnings/Images/dot-300x168.jpg")
plt.imshow(image2)

# %%
subtraced_image = cv2.subtract(image1,image2)
plt.imshow(subtraced_image)

# %% [markdown]
# ### Source :
#
# https://www.geeksforgeeks.org/python/opencv-python-tutorial/
